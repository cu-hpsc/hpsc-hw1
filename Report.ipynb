# %% [markdown]
# # HW1 Report
#
# Name:
#
# Collaborators:

# %% [markdown]
# # Part 1: Optimizing dot product

# %% [markdown]
# Write your analysis here.  You can use LaTeX-style math $n^2$ and
# $$ \sum_{i=0}^{n-1} a_i b_i .$$

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas
import numpy as np
plt.style.use('seaborn')

x = np.linspace(0, 2)
plt.plot(x, x**2)
plt.title('You can plot performance data');

# %% [markdown]
# # Part 2: Register a performance hypothesis

# %% [markdown]
# # Part 3: What can you achieve?

# %% [markdown]
# # Part 4: Reproducibility
